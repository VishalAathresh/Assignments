# %% [markdown]
# Python programming assignment

# %% [markdown]
# Exercise 1: Prime Numbers
#
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

#input and output
n = int(input("Enter a number: "))
print(f"{n} is {'prime' if is_prime(n) else 'not prime'}")
# Out:
# 3 is prime

# %% [markdown]
# Exercise 2: Product of Random Numbers
#
#
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
n1=random.randint(1,10)
n2=random.randint(1,10)

print(f'{n1}*{n2}?')
answer=int(input("answer is:"))


if answer == n1*n2:
    print("correct answer")
else:
    print(f"incorrect answer, The answer is {n1 * n2}")
# Out:
# 10*6?
# correct answer

# %% [markdown]
# Exercise 3: Squares of Even/Odd Numbers
#
#
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
print("squares of numbers from 100 to 200:")
for i in range(100,200):
    if i%2==0:
        print(f"{i}^2 = {i*i}")
    else:
        print(f"{i}^2 = {i*i}")
# Out:
# squares of numbers from 100 to 200:
# 100^2 = 10000
# 101^2 = 10201
# 102^2 = 10404
# 103^2 = 10609
# 104^2 = 10816
# 105^2 = 11025
# 106^2 = 11236
# 107^2 = 11449
# 108^2 = 11664
# 109^2 = 11881
# 110^2 = 12100
# 111^2 = 12321
# 112^2 = 12544
# 113^2 = 12769
# 114^2 = 12996
# 115^2 = 13225
# 116^2 = 13456
# 117^2 = 13689
# 118^2 = 13924
# 119^2 = 14161
# 120^2 = 14400
# 121^2 = 14641
# 122^2 = 14884
# 123^2 = 15129
# 124^2 = 15376
# 125^2 = 15625
# 126^2 = 15876
# 127^2 = 16129
# 128^2 = 16384
# 129^2 = 16641
# 130^2 = 16900
# 131^2 = 17161
# 132^2 = 17424
# 133^2 = 17689
# 134^2 = 17956
# 135^2 = 18225
# 136^2 = 18496
# 137^2 = 18769
# 138^2 = 19044
# 139^2 = 19321
# 140^2 = 19600
# 141^2 = 19881
# 142^2 = 20164
# 143^2 = 20449
# 144^2 = 20736
# 145^2 = 21025
# 146^2 = 21316
# 147^2 = 21609
# 148^2 = 21904
# 149^2 = 22201
# 150^2 = 22500
# 151^2 = 22801
# 152^2 = 23104
# 153^2 = 23409
# 154^2 = 23716
# 155^2 = 24025
# 156^2 = 24336
# 157^2 = 24649
# 158^2 = 24964
# 159^2 = 25281
# 160^2 = 25600
# 161^2 = 25921
# 162^2 = 26244
# 163^2 = 26569
# 164^2 = 26896
# 165^2 = 27225
# 166^2 = 27556
# 167^2 = 27889
# 168^2 = 28224
# 169^2 = 28561
# 170^2 = 28900
# 171^2 = 29241
# 172^2 = 29584
# 173^2 = 29929
# 174^2 = 30276
# 175^2 = 30625
# 176^2 = 30976
# 177^2 = 31329
# 178^2 = 31684
# 179^2 = 32041
# 180^2 = 32400
# 181^2 = 32761
# 182^2 = 33124
# 183^2 = 33489
# 184^2 = 33856
# 185^2 = 34225
# 186^2 = 34596
# 187^2 = 34969
# 188^2 = 35344
# 189^2 = 35721
# 190^2 = 36100
# 191^2 = 36481
# 192^2 = 36864
# 193^2 = 37249
# 194^2 = 37636
# 195^2 = 38025
# 196^2 = 38416
# 197^2 = 38809
# 198^2 = 39204
# 199^2 = 39601

# %% [markdown]
# Exercise 4:
# Problem Statement (Question): Hospital Billing System
# A hospital charges its patients based on the following:
# •	Room charges per day: ₹2,000
# •	Doctor consultation fee (flat): ₹1,500
# •	Lab test charges: Based on the number of tests taken. Each test costs ₹300
# •	Medicine charges: Total cost of medicines provided
# •	Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# Write a Python program to calculate the final bill for a patient who:
# •	Stayed for 4 days
# •	Had 3 lab tests
# •	Had medicine charges of ₹2,400

# %%
# Hospital Bill Calculator

# Fixed charges
room_per_day = 2000  # Fixed: was 1200, should be 2000 as per problem
doctor_fee = 1500
lab_fee = 300

# Patient details
days_lived = 4
lab_tests = 3
medicine_charge = 2400

# Calculate
room_charge = days_lived * room_per_day
lab_charge = lab_tests * lab_fee
total = room_charge + doctor_fee + lab_charge + medicine_charge

# Apply discount
discount = total * 0.10 if total > 10000 else 0
final_bill = total - discount

# Print bill
print("Hospital Bill:")
print(f"Room ({days_lived} days): ₹{room_charge}")
print(f"Doctor: ₹{doctor_fee}")
print(f"Lab Tests ({lab_tests}): ₹{lab_charge}")
print(f"Medicine: ₹{medicine_charge}")
print(f"Subtotal: ₹{total}")
if discount > 0:
    print(f"Discount (10%): -₹{discount}")
print(f"Final Bill: ₹{final_bill}")
# Out:
# Hospital Bill:
# Room (4 days): ₹8000
# Doctor: ₹1500
# Lab Tests (3): ₹900
# Medicine: ₹2400
# Subtotal: ₹12800
# Discount (10%): -₹1280.0
# Final Bill: ₹11520.0
